# %% [markdown]
# Neural Net:
# $$f_{\phi}(x)=W_3 \sigma (W_2 \sigma (W_1 x+b_1)+b_2)+b_3$$
# $ \sigma$ is ReLu
# $$x\in \mathbb{R}^{input para}$$
# Synthetic variables created with LHS
# $$x=[~v_0, ~\theta, ~\rho, ~\kappa, ~\xi, ~r, ~\tau, ~k, ~S]^{\top} $$
# $$W_1 \in \mathbb{R}^{512xinput}, ~W_2 \in \mathbb{R}^{512x512}, ~W_3 \in \mathbb{R}^{1x512}$$
# Weights and biases created for Neural Net trained on synethic data
# $$\phi=(W_1,b_1,W_2,b_2,W_3,b_3)$$
# $$x_i=[~v_0^{(i)}, ~\theta^{(i)}, ~\rho^{(i)}, ~\kappa^{(i)}, ~\xi^{(i)}, ~r^{(i)}, ~\tau^{(i)}, ~k^{(i)}, ~S^{(i)}]^{\top}$$
# Training loss:
# $$J_{train}(\phi)={1\over N}\sum_{i=1}^N(f_{\phi}(x_i)-y_i)^2$$
# $$\phi^*=argmin_{\phi}(f_{\phi}(x_i)-y_i)^2$$
# $$f_{\phi^*}(x)\approx P_{Heston}(x)$$

# %% [markdown]
# Find Heston parameters
# $$\Theta_{heston}=(v_0,\theta,\rho,\kappa,\xi)$$
# Market callibration Loss
# $$ L_{mkt}(\Theta_{Heston})={1\over M}\sum_{j=1}^{M}(f_{\phi^*}(x_j(\Theta_{Heston}))-p_j^{mkt})^2$$
